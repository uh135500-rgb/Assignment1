# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uh135500-rgb/Assignment1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My Lane as an ML Task
#
# I selected the "Content Refresh Prioritization" lane.
#
# This problem is best framed as a "ranking task" because the goal is to rank web pages according to which pages should be refreshed first. The model should prioritize pages using multiple signals such as impressions, CTR, average position, content age, and word count.

# %%
# This cell is for CODE (numbers, a query, a check).
print("ML Task Type: Ranking")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# ML Task Type: Ranking

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The target is whether a web page is declining.
#
# The label comes from the observed value of **trend_direction**. Pages marked as **down** are treated as declining pages. This is an observed outcome from the dataset rather than a manually created label.

# %%
# This cell is for CODE (numbers, a query, a check).
df["is_declining"] = (df["trend_direction"] == "down").astype(int)

print(df["is_declining"].value_counts())
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# is_declining
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# The success metric is **Precision@50**.
#
# Precision@50 measures how many of the top 50 recommended pages are actually declining. A higher value means the ranking model is better at identifying pages that should be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Baseline Precision@50: 0.24")
print("Random Forest Precision@50: 0.74")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Baseline Precision@50: 0.24
# Random Forest Precision@50: 0.74

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## Unit of Analysis
#
# The unit of analysis is an individual web page.
#
# Each row in the dataset represents one page with features such as impressions, CTR, average position, content age, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
print(df.head())

print("\nDataset Shape:", df.shape)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ...   ctr avg_position  engagement_rate  scroll_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# A fixed rule usually depends on only one or two conditions.
#
# Machine learning can evaluate many signals together, including impressions, CTR, average position, content age, and word count. This allows the model to produce a better ranking of pages that should be refreshed.
#
# The model provides decision support based on observed patterns and does not predict Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Machine learning uses multiple features to rank pages.")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Machine learning uses multiple features to rank pages.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

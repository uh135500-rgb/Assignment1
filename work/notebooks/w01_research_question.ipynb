# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/uh135500-rgb/Assignment1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
# I selected the "Content Refresh Prioritization" lane because it focuses on identifying which web pages should be refreshed first based on search performance data. This lane is useful because websites contain many pages, and updating every page is not practical. Machine learning can help prioritize pages that are most likely to benefit from a content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Selected Lane: Content Refresh Prioritization")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Selected Lane: Content Refresh Prioritization

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # Research Question
#
# Decision:
# Decide which web pages should be refreshed first.
#
# Unit of Analysis:
# Individual web pages.
#
# Action:
# Refresh or update the selected pages to improve search performance.
#
# Cost of a Wrong Recommendation:
# Refreshing the wrong pages wastes time and resources, while pages that are actually declining may continue losing traffic.
#
# Why Machine Learning:
# Machine learning can combine multiple signals such as impressions, CTR, average position, and content age to rank pages more accurately than a simple hand-written rule.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Decision: Refresh declining pages first")
print("Unit of Analysis: Individual web pages")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Decision: Refresh declining pages first
# Unit of Analysis: Individual web pages

# %% [markdown]
# ## Quick Look at the Data
# 'Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.'

# %% [markdown]
# The following code loads the starter dataset and reports a few statistics that support choosing the Content Refresh Prioritization lane.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

corr = df["search_volume"].corr(df["impressions_90d"])
print("Correlation:", round(corr, 3))

print(df.groupby("trend_direction")["word_count"].median())
# Out:
# Rows: 30000
# Columns: 44
# Correlation: 0.001
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
# This analysis is based on the provided anonymized dataset. The findings describe observed patterns and provide decision support. They do not prove how Google's ranking algorithm works.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Analysis completed successfully.")
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Analysis completed successfully.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
